# %% [markdown]
# ### Variables
#     Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %% [markdown]
# Video Outline:
#     - Introduction to Variables
#     - Declaring and Assigning Variables
#     - Naming Conventions
#     - Understanding Variable Types
#     - Type Checking and Conversion
#     - Dynamic Typing
#     - Practical Examples and Common Errors

# %%
a = 100

# %%
## Declaring And Assigning Variables

age = 27
name = "Ayush"
height = 5.5
is_student = True

## Printing Variables
print("Age:", age)
print("Name:", name)
print("Height:", height)
print("Is Student:", is_student)
# Out:
# Age: 27
# Name: Ayush
# Height: 5.5
# Is Student: True

# %%
## Naming Conventions
## Variable names should be descriptive and use snake_case for better readability.
## They must start with a letter or underscore and can contain letters, digits, and underscores.
## Varaible names are case-sensitive.

# Valid variable names
first_name = "Ayush"
last_name = "Dhiman"

# %%
# Invalid variable names
# 2age = 30 
# first-name = "Ayush"
# @name = "Ayush"

# %%
## Case Sensitivity
name = "Ayush"
Name = "Dhiman"

# %%
## Understanding Variable Types
## Python is a dynamically typed language, which means you don't need to declare the type of a variable explicitly. The interpreter infers the type based on the assigned value.

age = 25 #integer
height = 5.5 #float
name = "Ayush" #string
is_student = True #boolean

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
## Type Checking and Conversion
# Checking the type of a variable
print(type(age))  # Output: <class 'int'>

# Converting types
age = 25
print(type(age))  # Output: <class 'int'>
age_str = str(age)  # Convert integer to string
print(age_str)       # Output: '25'
print(type(age_str))  # Output: <class 'str'>
# Out:
# <class 'int'>
# <class 'int'>
# 25
# <class 'str'>

# %%
age = '21'
print(type(int(age)))  # Convert string to integer and check type
# Out:
# <class 'int'>

# %%
name = 'Ayush'
int(name)  # This will raise a ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 name = 'Ayush'
# ----> 2 int(name)  # This will raise a ValueError
#
# ValueError: invalid literal for int() with base 10: 'Ayush'

# %%
height = 5.5
type(height)  # Convert float to integer
# Out:
# float

# %%
int(height)  # This will return 5
# Out:
# 5

# %%
## Dynamic Typing
## Python allows the type of a variable to change as program executes

var = 10 # int
print(var, type(var))  # Output: 10 <class 'int'>

var = "Hello" # str
print(var, type(var))  # Output: Hello <class 'str'>

var = 3.14 # float
print(var, type(var))  # Output: 3.14 <class 'float'>
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## Input

age = int(input("What is your age? "))
print("Your age is:", age)
print("Type of age variable:", type(age))  # Output: <class 'str'
# Out:
# Your age is: 23
# Type of age variable: <class 'int'>

# %%
 ### Simple calculator
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))
sum_val = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2
   
print("Sum:", sum_val)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 99.0
# Difference: 13.0
# Product: 2408.0
# Quotient: 1.302325581395349
